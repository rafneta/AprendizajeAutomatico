# %%
from Programas.IAc1 import *
from IPython.core.display import HTML
css_file = 'Varios/css/estilo1.css'
HTML(open(css_file, "r").read())
# Out:
# <link href='http://fonts.googleapis.com/css?family=Alegreya+Sans:100,300,400,500,700,800,900,100italic,300italic,400italic,500italic,700italic,800italic,900italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Arvo:400,700,400italic' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=PT+Mono' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Shadows+Into+Light' rel='stylesheet' type='text/css'>
# <link href='http://fonts.googleapis.com/css?family=Nixie+One' rel='stylesheet' type='text/css'>
# <link href='https://fonts.googleapis.com/css?family=Source+Code+Pro' rel='stylesheet' type='text/css'>
# <style>
#
# @font-face {
#     font-family: "Computer Modern";
#     src: url('http://mirrors.ctan.org/fonts/cm-unicode/fonts/otf/cmunss.otf');
# }
#
# #notebook_panel { /* main background */
#     background: rgb(255,255,255);/*rgb(245,245,245);*/
# }
#
# ...

# %% [markdown]
# # Aprendizaje supervisado
# <p>Dada una estrada esta se le debe asociar una determinada salida. POr ejemplo el porblema de <strong>clasifiación:</strong> Clasificar tipos de imagenes, identificar cuentas de redes sociales aprocrifas, reconosimiento de digitos escritos a mano </p>
#
# <p>Aqui se tienen una cantidad de datos que sirven de entrenamiento, el usuario provee de las salidas correctas (etiquetas) </p>
#
# <p>Los datos se deben de separa en datos de entrenamiento y datos de prueba</p>
#
# <p>El comportamiento de la predicción puede ser diferente de los datos de entrenamiento respectoa laso atos de prueba, esto se conoce como overfitting</p>
#
# <p>Por otro lado se tiene el algoritmo del vecino mas cercano qeu es asignar un aclasificación de acuerdo a una distancia definiida y calculando cual es el menor valor</p>
#
# <p>Un algoritmo de aprendizaje supervisado toma un conjunto conocido de datos de entrada (el conjunto de entrenamiento) y respuestas conocidas a los datos (salida), y entrena un modelo para generar predicciones razonables para la respuesta
# a nuevos datos de entrada. Utilice el aprendizaje supervisado si tiene datos existentes para la salida que intenta predecir.</p>
#
#
# <p>Como vimos en la sección 1, seleccionar un algoritmo de aprendizaje automático es un proceso de prueba y error. También es una compensación entre las características específicas de los algoritmos, tales como:
# <br> Velocidad de entrenamiento
# <br> Uso de memoria
# <br> Precisión predictiva en nuevos datos
# <br> Transparencia o interpretabilidad (qué tan fácil puede entender las razones por las cuales un algoritmo hace sus predicciones)
# Echemos un vistazo más de cerca a los algoritmos de clasificación y regresión más comúnmente utilizados.</p>
#
# <ul>
#     <li><p><strong>Tecnicas de clasifiación.</strong> Predecir respuesta discretas, por ejemplo: Cuando un email es genuido o publicidad, cuando un tumor es canceroso o benigno. Clasificación de modelos clasificar entradas dentro de categorias. Imagenes medicas, reconocimineto de voz e historial crediticio. </p></li>
#     <ul>
#         <li><p>Regresión logistica. Ajusta un $x_2$ modelo que puede predecir la porbabilidad de que una respuesta pertenenzca a una clase o a otra (clasificacion binaria). Es usada para inicialisar un problema de clasificación binario. Se usa cuando los datos pueden separarse por una simple barrera lineal, es una base para aplicar metodos de clasificación más complejos</p>
#
#
#
#  <li><p>k vecino más cercano (k Nearest Neighbot KNN). Clasiifca los objetos en clases de canjuntos de sus vecinos más cercanos. Distancias métricas euclideanas, Chebychev son usadas. Cuandi se necesita un algoritmo simple para establecer comparaciones de reglas de aprendizaje. Cuando el uso de la memoria del modelo entrenado es una preocupación menor. Cuando la velocidad de predicción del modelo entrenado es una preocupación menor</p> </li>
#
#  <li>Maquinas de Soporte vectorial (Support Vector Machine SVM). Clasifica datos encontrando un abarreara lineal de desición, que separa los puntos de una clase respecto de otra clase, cuando los datos son lnealmente separable. , usualmente usan un kernel de separación no lineal para separar los datos en un espacio donde sea posible la separación. Se usa cunando los datos tienen exactamento dos clases</li>
#
#
#   <li>Redes Neuronales. INspiradas en el cerebro humano, consiste en redes conectadas de nueronas que relacionan las entradas con las salidas deseadas, la red es entrenada modificando los valores de los pesos dando un mapeo de la entrada con la correspondiente respuesta, Se usan para modelar sistemas no lineales, cuando la cantidad e datos incrementa y usualmente estas cambiando el modelo, cuando se esperan cambios inesperados en los datos de entrada cuando la interpretación del modelo no es una preocupación. </li>
#
#  <li>Naive Bayes (Bayes sencillo). Asume que la presencia de una caracteristica particular en una clase no está relacionada con la presencia de ninguna otra característica. Clasifica nuevos datos según la probabilidad más alta de pertenecer a una clase en particular. Se usa para pequeos conjuntos de datos con muchos parametros, cuando se necesita un clasificador facíl de interpretar, Cuando el modelo encontrará escenarios que no estaban en los datos de capacitación, como es el caso de muchas aplicaciones financieras y médicas</li>
#
#  <li>Análisis discriminante. El análisis discriminante clasifica los datos al encontrar combinaciones lineales de características. El análisis discriminante supone que las diferentes clases generan datos basados en distribuciones gaussianas. El entrenamiento de un modelo de análisis discriminante implica encontrar los parámetros para una distribución gaussiana para cada clase. Los parámetros de distribución se utilizan para calcular los límites, que pueden ser funciones lineales o cuadráticas. Estos límites se usan para determinar la clase de datos nuevos. cuando se necesita un modelo simple facíl de interpretar, cuando el uso de memoria durante el entrenamiento es un problema, cuando se necesita unmodelo rapido para predecir</li>
#
# <li>Arboles de desición. Permite predecir respuestas a datos siguiendo desiciones en el arbol desde l raiz hast uno de los nodos, el arbol consiste en una rama de desición donde el valor de un predictor es comparado con un peso de entrenamiento, en numero de ramas y vaores es determinado en el proceso de entrenamiento. Se usa cuando se necesita un algoritmo que es facil de interpretar y facil de ajustar, para minimizar el uso de memoria, cuando una alta presicion pedictiva no es un requisito </li>
#
# <li>Árboles de decisión empaquetados y potenciados. Se combinan arboles en un ensamble fuerte, tomas un conjunto de arboles y los inicilizas con datos de entrada. despes se ajustan los psos de cada arbol.  cuando los datos son categoricos discretos, o tienen nolinealidad. cuando el tiempo de entrenamiento no es un problema</li>
# </ul>
#
# <li><strong>Tecnicas de regresiónn.</strong> Predice respuestas continuas. Cambio en temperatira o demanda de potencia predicciñon de carga electrica, Algoritmic trading</li>
#      <ul>
#
# <li>Regresión lineal. Es una tecnica de modelado estadístico usado para describir una respuesta de una varibale continua como una función lineal de varables predictor. Se usa cuando se necesita una añgoritmo que es facil de interpretar y rapido de ajustar, como base para otros modelos de regreción más complejos</li>
#
# <li>Regresión no lineal. Similar a regresión lineal pero la relación es no lineal en los parametros. Se usa cuando los datos tienen comportamientos no lineales, para ajustar modelos a datos. </li>
#
# <li>Modelo de regresión del proceso gaussiano (GPR). Son modelos no parametricos que son usados para predecir el valor de una varibale continua, son usados para la el analisis espaciales para interpolacion en la presencia de incertidumbre tambien conocido como Kriging. SE usa para interpolar datos espaciales, Como un modelo sustituto para facilitar la optimización de diseños complejos, como los motores de automóviles </li>
#
# <li>Regresión SVM. Son como los SVM pero son modificados para predecir una respuesta continua. Encuantra un modelo y una desviación de los datos. Se usan para datos de grandes dimensiones.</li>
#
# <li>MOdelo lineal generalizado. Es una generalizaciñon del modelos lineales al codso de odelos no lineales que usa metodos lineales. Ajunta una combinaciñon lineal de las entradas a una función no lineal de la salida. Se usa cuando las respuesta de las variables tiene un distribución no normal donde se espera que la respuesta siempre sea positiva.</li>
#
# <li>Arbol de regresión. Sonsimilares a los arboles de desición para la clasificación, pero son modificados para predecir respuestas continuas. Se usan cuando los predictores son categoricos discretoo presentan comportamiento no lineal</li>
# </ul>
# </ul>
#
# <p>
# <strong>Mejoramiento de modelos</strong>
# </p>
# <p>Mejorar un modelo significa aumentar su precisión y poder predictivo y evitar el sobreajuste (cuando el modelo no puede distinguir entre datos y ruido). La mejora del modelo involucra ingeniería de características (selección y transformación de características) y ajuste de hiperparámetros.</p>
#
# <ul>
#     <li>Selección de características: identificación de las características más relevantes, o variables, que proporcionan la mejor capacidad de predicción al modelar sus datos. Esto podría significar agregar variables al modelo o eliminar variables que no mejoran el rendimiento del modelo.</li>
#     <li>Transformación de características: convierte características existentes en nuevas características utilizando técnicas como el análisis de componentes principales, la factorización de matrices no negativas y el análisis de factores.</li>
#     <li>Ajuste de hiperparámetros: el proceso de identificación del conjunto de parámetros que proporciona el mejor modelo. Los hiperparámetros controlan cómo un algoritmo de aprendizaje automático se ajusta al modelo de los datos.</li>
# </ul>
#
#
# <div class="polaroid">
#    <img src="./Varios/imagenes/Matlab3.png" alt="Pareja" width="80%" height="80%">
#   <div class="despolaroid">
#     <p>Esta imagen será remplazada por una propia</p>
#   </div>
# </div>
#
#
# <strong>Selección de características</strong>
# <p>La selección de funciones es una de las tareas más importantes en el aprendizaje automático. Es especialmente útil cuando se trata de datos de gran dimensión o cuando su conjunto de datos contiene una gran cantidad de características y un número limitado de observaciones. La reducción de características también ahorra tiempo de almacenamiento y computación y hace que sus resultados sean más fáciles de entender.
# Las técnicas comunes de selección de características incluyen:</p>
#
# <ul>
#     <li>Regresión paso a paso: agregar o eliminar funciones secuencialmente hasta que no haya una mejora en la precisión de la predicción.</li>
#     <li>Selección secuencial de características: Agregue o elimine iterativamente variables de predicción y evalúe el efecto de cada cambio en el rendimiento del modelo.</li>
#     <li>Regularización: utilizar estimadores de contracción para eliminar las características redundantes al reducir sus ponderaciones (coeficientes) a cero</li>
#     <li>Análisis de componentes de vecindad (NCA): determinar el peso que cada característica tiene para predecir la salida, de modo que las características con menos peso se puedan descartar.</li>
# </ul>
#
# <strong>Transformación de características</strong>
#
# <p>La transformación de características es una forma de reducción de dimensionalidad. Como vimos en la sección 3, las tres técnicas de reducción de dimensionalidad más comúnmente utilizadas son:</p>
#
# <ul>
#     <li>Analisis de Componentes prncipales. Realiza una transformacion lineal de los datos donde la mayor varianza o informacion de todas las variables es capturada por sus principales componentes. Esta importacua es jerarquizada por la primera variables la segunda, esto lo he hecho en econometria. Cad componente pricipal es una combinacion lineal de las primeras variables donde no hay información redundante pues son ortoganles entre si </li>
#     <li>analissi de Factor. Identifica la correlació entre las variables para proveer de una representacion en terminos de una numero peueño de factors comunes o latentes. Puede que tengas varibles que dependan entre si ( se traslapen) esta tecnica te permite obtener un modelo que estima el orden de dependencia, piensas que estas varibales dependen de diferentes factores por lo que extraes estos factores y expresas las variables como una combinación lineal de ellos</li>
#     <li>Factorizaciñon d mAtrices no NEgativa. Usada cuando los terminos del modelo deben epresentacrse en cantidades no negativas como cantidades fisicas. Esta tecnica esta basada en un esacio de aproximación de rango bajo.</li>
# </ul>
#
# <strong>Ajuste de hiperparámetros</strong>
#
# <p>Al igual que muchas tareas de aprendizaje automático, el ajuste de parámetros es un proceso iterativo. Comienza por establecer los parámetros según una "mejor estimación" del resultado. Su objetivo es encontrar los valores "mejores posibles", los que producen el mejor modelo. A medida que ajusta los parámetros y el rendimiento del modelo comienza a mejorar, puede ver qué parámetros son efectivos y cuáles requieren sintonía.
# Tres métodos comunes de ajuste de parámetros son:
# <br>• Optimización bayesiana
# <br>• Búsqueda de cuadrícula
# <br>• Optimización basada en gradientes</p>
#
# prueb de ajuste

# %% [markdown]
# ## Regresión Logistica
#
# <p>Regresión logistica. Ajusta un $x_2$ modelo que puede predecir la porbabilidad de que una respuesta pertenenzca a una clase o a otra (clasificacion binaria). Es usada para inicialisar un problema de clasificación binario. Se usa cuando los datos pueden separarse por una simple barrera lineal, es una base para aplicar metodos de clasificación más complejos</p>
#
#
#  <p> Es un metodo clásico, utiliza la función de pérdida $log(1-e^{-yf(x)})$ minimizamos</p>
#
#  $$\min\limits_{moldels\;f}\frac{1}{n}\sum_{i=1}^n log(1+e^{-y_if(x_i)})$$
#  <p>
#   \begin{equation}
#   \label{foo}
#   f(\bar{x}_i)=\sum_{j=1}^p \beta_jx_{ij}
#   \end{equation}
#    </p>
#  <p>Así se tiene que la regresion logistica es
#    <p>
#   \begin{equation}
#     \label{reglogidtica}
#    \min\limits_{\;\beta_1\ldots\beta_p}\frac{1}{n}\sum_{i=1}^n log\left(1+e^{-y_i\sum\limits_{j=1}^p \beta_jx_{ij}}\right)
#        \end{equation}
#      </p>
#
#
# <p> La función logistica inventada por verhultz </p>
#
# \begin{equation}
# f(t)=\frac{e^t}{1+e^t}
# \end{equation}
#
#
# \begin{equation}
# \mathbb{P}(Y_i=1|\bar x_i,\beta)=\frac{e^{\bar x_i\beta}}{1+e^{\bar x_i\beta}}
# \end{equation}
#
# <p>donde $\bar x_i\beta=\sum\limits_{j=1}^p x_{ij}\beta_j$</p>
#
# \begin{equation}
# \mathbb{P}(Y_i=-1|\bar x_i,\beta)=1-\frac{e^{\bar x_i\beta}}{1+e^{\bar x_i\beta}}=\frac{1}{1+e^{\bar x_i\beta}}
# \end{equation}
#
#
# <p>La minimizaciñon se puede interpretar como un problema de maxima verisimilitud, bueno solo verosimilitud, de esa manera se puede demostrar la forma de la funcióna minimizar. Los pasos para la regresión logistica ze pueden resumir en lso siguientes</p>
#
# <div class="algoritmo">
#     <strong>Algoritmo: Regresión logística</strong>
# <ul class="nobullet">
#     <li><p><strong>Paso 1.</strong> Separar los datos aleatoriamente para entrenamiento y para prueba </p></li>
#     <li><p><strong>Paso 2.</strong> Estimación de los coeficientes (entrenamiento del modelo) </p></li>
#
#   $$\hat{\beta}=\min\limits_{\;\beta_1\ldots\beta_p}\frac{1}{n}\sum_{i=1}^n log\left(1+e^{-y_i\sum\limits_{j=1}^p \beta_jx_{ij}}\right)$$
#
#
# <li><p><strong>Paso 3.</strong> Califica el modelo, para cada $\bar x_i$ en el conjunto de prueba </p></li>
#
#   $$f(\bar{x}_i)=\sum_{j=1}^p \hat{\beta}_jx_{ij}$$
#
#
#  <li><p><strong>Paso 4.</strong> Se evalúa el modelo</p></li>
# </ul>
# </div>

# %% [markdown]
# <div class="laboratorio">
#
#
# <h3>Laboratorio: Regresión logística</h3>
# <div class='skillset'>
# <div class="projects-button">
#     Desplegar</div>
# <div class='projects'>
# <h4>Crear cuentas de Microsoft</h4>
#
# <ol>
#     <li><p>Crear una cuenta de Microsoft (si es que no se tiene una) <a href="https://signup.live.com/">https://signup.live.com/</a> </p></li>
#
#    <li><p>Crear una cuenta en <em>Azure ML</em> (si es que no se tiene una) <a href="https://aka.ms/edx-dat203.2x-aml"> https://aka.ms/edx-dat203.2x-aml</a> seleccionar <em>Get Started Now</em> y obtener una cuenta gratuita. Esta cuenta tiene limitaciones en cuanto porcesamiento y espacio</p></li>
#
#    <li><p>Descargar los archivos de laboratorio<a href="https://aka.ms/edx-dat203.2x-labfiles"> https://aka.ms/edx-dat203.2x-labfiles</a> posteriormente descomprimir estos archivos</p></li>
# </ol>
#
#
#
# <h4>Introducción</h4>
#
#
# <p>En este laboratorio se trabajará con datos de pascientes de diabetes ingresados en hospitales de EUA. Entrenará y evaluará un modelo de clasificación para predecir que pascientes diabéticos serán readmitidos en una fecha posterior. La readmisión de los pascientes en una medida tanto de la atención deficiente como de la carga financiera al pasciente, las aseguradoras, el gobierno y de los provedores de servivio de atención medica. Para ello se tiene que</p>
#
# <ul>
#     <li><p>Preparar los datos para su analisis</p></li>
#
#    <li><p>Visualizar los datos con Python para investigar su relación</p></li>
#
#    <li><p>Crear un modelo de clasificación logística</p></li>
#
#    <li><p>Evaluar el desempeño del modelo de clasificación</p></li>
# </ul>
#
# <h4>Preparar el conjunto de datos</h4>
#
# <ol>
#     <li><p>Iniciar sesión en <a href="https://studio.azureml.net/">https://studio.azureml.net/</a> con la cuenta asociada a <em>Azure ML</em> </p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab11.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Sesión Azure ML</p>
#   </div>
# </div>
#     </li>
#
#   <li><p>Crear un nuevo experimento (parte inferior izquierda) con el nombre Diabetes-Clasificacion</p>
#
#   <div class="polaroid">
#    <img src="./Varios/imagenes/Lab12.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Nuevo experimento</p>
#   </div>
# </div>
# </li>
#
#    <li><p>Dar click en NEW (parte inferior izquierda) y en el cuadro de dialogo seleccionar DATASET</p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab13.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Seleción del DATASET</p>
#   </div>
# </div>
# </li>
#
# <li><p>Dar click en FROM LOCAL FILE, posteriormente seleccionar la ruta del archivo diabetic_data.csv que se descargo en su equipo previamente, verifique  que las sigueintes opciones</p>
#
# <ul>
#     <li><p>This a new version of an existing dataset: No seleccionado</p></li>
#     <li><p>Enter a name for the new dataset: diabetic_data.csv</p></li>
#     <li><p>Select a type for the new dataset: Generic CSV file with a header (.csv)</p></li>
#     <li><p>Provide an optional description: Pascientes con diabetes datos de readmision</p></li>
#  </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab14.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Cargar el DATASET</p>
#   </div>
# </div>
#
#  <p>Posteriormente confirme</p>
# </li>
#
#
#  <li><p>Espere a que los datos se carguen, en el panel del experimento busque Saved datasets - My Datasets verifique que aparezca el archivo diabetic_data.csv</p>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab15.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>El DATASET se cargó correctamente</p>
#   </div>
# </div>
# </li>
#
#
#  <li><p>Repita los pasos previos para cargar el archivo admissions_mapping.csv con las sigueintes propiedades</p>
#
# <ul>
#     <li><p>This a new version of an existing dataset: No seleccionado</p></li>
#     <li><p>Enter a name for the new dataset: admissions_mapping.csv</p></li>
#     <li><p>Select a type for the new dataset: Generic CSV file with a header (.csv)</p></li>
#     <li><p>Provide an optional description: Codigos de admision</p></li>
#  </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab16.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>El DATASET se cargó correctamente</p>
#   </div>
# </div>
#  </li>
#
#  <li><p>Arrastre los DATASET diabetic_data.csv y admissions_mapping.csv al lienzo del lado derecho</p>
#
#   <div class="polaroid">
#    <img src="./Varios/imagenes/Lab17.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>DATASET en el lienzo</p>
#   </div>
# </div>
#  </li>
#
#   <li><p>En el lienzo seleccione diabetic_data.csv, de click derecho y selecione dataset-Visualize para ver los datos</p>
#
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab18.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Valores de los datos</p>
#   </div>
# </div>
#
#
# <p>Entre otros datos se observa la columna con el nombre readmitted que indica si  el pasciente ha sido admitido, y de ser así se muestra el número de días antes de la readmisión como mayores o menoes que 30. Se ahan elaborado miles de observaciones (pascientes), el modelo tendra que predecir la columna de ewadmitted indicando si el pasciente ha sido o no readmitido, simpliifcando los tres posibles valores a dos.</p>
# </li>
#
#  <li><p>En el lienzo seleccione admissions_mapping.csv, de click derecho y selecione dataset-Visualize para ver los datos</p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab19.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Valores de los datos</p>
#   </div>
# </div>
#
#
# <p>Se observan dos columnas, el tipo de admisión y su descripción. Observe que existe ambiguedad en algunos datos pues los datos daltantes se codifican en distintas formas: Not Available, NULL, y Not Mapped</p>
# </li>
#
#  <li><p>En el panel del experimento busque Python Lenguage Modules - Execute Python Script y agregue este módulo al lienzo del experimento. Conecte la salida del archivo admissions_mapping.csv al Dataset1 (la entrada izquirda) del módulo </p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab110.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agregó el módulo Execute Python Script </p>
#   </div>
# </div>
# </li>
#
#  <li><p>Seleccione el módulo Execute Python Script, a la derecha del lienzo aparecera un cuadro (Python Script) para ingresar código, agregue en este lugar el contenido del archivo CleanAdmissions.py (se descargo previamente), seleccione la versión de Python más reciente disponible</p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab111.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se actualiza el Python Script </p>
#   </div>
# </div>
#
#
#  <p>Este código genera una códificación consistente, todos los datos no disponibles se cambian por la descripción <em>unknown</em></p>
# </li>
#
#
# <li><p>Busque el módulo Data Transformation - Manipulation - Join Data y agreguelo al lienzo del experimento. Conecte la salida del diabetic_data.csv a la entrada izquierda (Dataset1) de este módulo y en la entrada derecha (Dataset2) coloque la salida izquierda (Results Dataset) del Execute Python Scipt. Verifique la configuración del Join Data</p>
#
# <ul>
#     <li><p>Join key columns for L Column names: admissions_type_id</p></li>
#     <li><p>Join key columns for R Column names: admissions_type_id</p></li>
#     <li><p>Match case: Seleccionado</p></li>
#     <li><p>Join type: Left Outer Join</p></li>
#     <li><p>Keep right key columns in joined table: No seleccionado</p></li>
# </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab112.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agregó el módulo Join Data </p>
#   </div>
# </div>
# </li>
#
# <li><p>Agregue el módulo  Data Transformation - Manipulation - Clean Missing Data y conecte a su entrada la salida del módulo Join Data, verifique las siguientes propiedades</p>
#
# <ul>
#     <li><p>Columns to be cleaned: String, All (NO COLUMS, include, column type, String)</p></li>
#     <li><p>Minimum missing value ratio: 0</p></li>
#     <li><p>Maximum missing value ratio: 1</p></li>
#     <li><p>Cleaning mode: Custom substitution value</p></li>
#     <li><p>Replacement value: unknown</p></li>
#     <li><p>Generate missing value indicator column: no seleccionado</p></li>
# </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab113.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agregó el módulo Celan Missing Data</p>
#   </div>
# </div>
#
#
# <p>Esto reemplaza cualquier cadena faltante con el texto <em>unknown</em></p>
# </li>
#
# <li><p>Agregue un nuevo módulo  Data Transformation - Manipulation - Clean Missing Data y conecte a su entrada la salida izquierda del módulo Clean Missing data previo, verifique las siguientes propiedades</p>
#
# <ul>
#     <li><p>Columns to be cleaned: Numeric, All (NO COLUMS, include, column type, Numeric)</p></li>
#     <li><p>Minimum missing value ratio: 0</p></li>
#     <li><p>Maximum missing value ratio: 1</p></li>
#     <li><p>Cleaning mode: Custom substitution value</p></li>
#     <li><p>Replacement value: 0 </p></li>
#     <li><p>Generate missing value indicator column: no seleccionado</p></li>
# </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab114.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agregó un nuevo módulo Celan Missing Data</p>
#   </div>
# </div>
#
# <p>Esto reemplaza cualquier valor faltante con 0</p>
# </li>
#
# <li><p>Guarde y ejecute (RUN) el experimento, verifique que la salida del último módulo Clean Missing Data no existan valores faltantes (Seleccionar el módulo, click derecho Cleaned dataset-Visualize)</p>
#
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab115.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se verifica la ejecución</p>
#   </div>
# </div>
# </li>
#
# <li><p>Agregue un módulo Execute Python Script al experimento y conecte a su entrada izquierda (Dataset1) la salida izquierda del último módulo Clean Missing Data, dentro del módulo de Python ingrese el código del archivo SetDiagCodes.py que descargo previamente, ejecutamos para verificar que todo es correcto</p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab116.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agrega un módulo de Python</p>
#   </div>
# </div>
#
# <p>Este código tabaja con algunos códigos no numericos para los códigos especiales de diagnostico y transforma códigos numéricos indexando un vector de códigos de texto.</p>
#
# <li><p>Agregue un módulo más Execute Python Script al experimento y conecte a su entrada izquierda (Dataset1) la salida izquierda del módulo anterior Execute Python Script, dentro del módulo de Python ingrese el código del archivo SetReadmit.py que descargo previamente, ejecutamos para verificar que todo es correcto</p>
#
# <div class="polaroid">
#    <img src="./Varios/imagenes/Lab117.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se agrega un módulo de Python</p>
#   </div>
# </div>
#
# <p>Este código transforma las tres categorias (No,&lt;30,&gt;30) de readmitido a dos, lo cual es necesario para el tipo de clasificación a realizar. Ejecute y revise que el contenido de la columna de readmitted sólo contenga dos valores (YES, NO) (Seleccione la salida izquierda del último módulo de Python, click en botón derecho posteriormente en el cuadro de dialogo seleccionar Visualize) </p>
# </li>
#
# <li><p>Agregar el Módulo Select Columns in Dataset (navegar en Data Transformation - Manipulation), conectar a su entrada la salida izquierda del módulo de Pyhton, Posteriormente seleccione el column selector para para excluir las siguietes columnas</p>
#    <ul>
#     <li><p>admission_type_id</p></li>
#     <li><p>encounter_id</p></li>
#     <li><p>patient_nbr</p></li>
# </ul>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab118.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se exluyen tres columnas</p>
#   </div>
# </div>
#
# <p>Esto remueve columnas que no tienen información importante</p>
# </li>
#
# <li><p>Agregue un módulo Normalize Data (navegar a Data Transformation- Scale and Reduce), y conecte la salida del módulo anterior a este módulo, verifique en el módulo las siguientes propiedades </p>
#   <ul>
#     <li><p>Transformation method: ZScore</p></li>
#     <li><p>Use 0 for constant columns when checked: Seleccionado</p></li>
#     <li><p>Columns to transform:</p>
#        <ul>
#     <li><p>time_in_hospital</p></li>
#     <li><p>num_lab_procedures</p></li>
#     <li><p>num_procedures</p></li>
#     <li><p>num_medications</p></li>
#     <li><p>number_outpatient</p></li>
#     <li><p>number_emergency</p></li>
#     <li><p>number_inpatient</p></li>
#     <li><p>number_diagnoses</p></li>
#        </ul>
#       </li>
# </ul>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab119.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se normalizan algunas columnas</p>
#   </div>
# </div>
#
# <p>Esto normaliza las columnas numéricas continuas en el conjunto de datos. Algunas otras columnas numéricas son utilizadas para variables categóricas, y no deben ser normalizadas.</p>
# </li>
#
# <li><p>Agregue el módulo Edit Metadata (navegar a Data Transformation - Manipulation) y conecte la salida izquierda del módulo anterior a su entrada, Verifique la selección de las siguientes propiedades</p>
#
#
# <ul>
#     <li><p>Column: All string columns</p></li>
#     <li><p>Data type: Unchanged</p></li>
#     <li><p>Categorical: Make categorical</p></li>
#     <li><p>Fields: Unchanged</p></li>
#     <li><p>New column named: Dejar en blanco </p></li>
# </ul>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab120.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se cambian los tipos de datos</p>
#   </div>
# </div>
#
# <p>Esto cambia las cadenas a variables categoricas, ejecute para verificar que no hay erorres.</p>
# </li>
# </ol>
#
# <h4>Visualización de los datos</h4>
#
# <p>En esta parte se utilizará un código de Python para ver la relación entre los datos, los datos son numerico y categoricos, nuestra columna objetivo es la de readmitted que puede ser "YES" o "NO" lo cual, como hemos comentado, genera un problema de clasificación binaria. Se estudiará la relación con los datos y esta columna.</p>
#
# <ol>
#     <li><p>Agregue el módulo Convert to CSV (navegar a Data Format Conversions) y conectar a su entrada la salida del módulo Edit Metadata, posteriormente ejecutar el experimento</p>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab121.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se genera un archivo de los datos</p>
#   </div>
# </div>
# </li>
#
# <li><p>En la salida del módulo Convert to CSV hacer clic derecho y selecccinar Open in a new workbook- Python 3, aparecerá un notebook con un código que carga el archivo de los datos antes mecionados , en el menu Cell (del notebook) seleccionar Run All. Guarde el notebook constantemente</p>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab122.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se ejecuta el notebook</p>
#   </div>
# </div>
# </li>
#
# <li><p>En el menu Cell, dar click en Insert Cell Bellow para generar una nueva celda e insertar el contenido del archivo VisualizeDiabetes.py que se ha descargado previamente, ejecutar esta celda con el botón de play o nuevamente en el menu Cell (del notebook) seleccionar Run All</p>
#      <div class="polaroid">
#    <img src="./Varios/imagenes/Lab123.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Se ejecuta el código en el notebook</p>
#   </div>
# </div>
# </li>
#
# <li><p>Cuando termine la ejecución insertar nuevamente una celda y agregar las siguientes lineas de código y ejecutarlas, la ejecución puede generar algunas advertencias y tarda algunos minutos</p>
#
#   <code>%matplotlib inline
# diabetes_hist(frame)
# diabetes_bar(frame)
# diabetes_box(frame)
# </code>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab124.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Ejecución del código</p>
#   </div>
# </div>
# </li>
#
# <li><p>Haga clic en la barra gris en el borde izquierdo del panel de salida que contiene las gráficas para ver toda la salida en la ventana principal del notebook</p>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab125.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Visualización de los datos</p>
#   </div>
# </div>
# </li>
#
# <li><p>Se preenta diferente información gráfica de los datos respecto a los pasciente readmitidos y los no readmitidos. POr ejmplo en la gráfica de Barras que se observa a continuacion, se puede ver la cantidad de pasicentes, ordenados de acuerdo a su edad, que fueron o no readmitidos, las edades están agrupadas por decadas. Se observa que hay una maypr cantidad de pascientes no readmitidos.</p>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab126.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Edad de los pascientes</p>
#   </div>
# </div>
# </li>
#
# <p>Hay un ligero sesgo hacia las edades más avanzadas para los pacientes que son readmitidos. Sin embargo, el efecto es sutil, lo que indica que esta característica solo contiene información mínima para separar las clases.</p>
# </li>
#
# <li><p>Si se examina el dato A1 Cresult (recordemos que todo es respecto a pascientes admitidos y no readmitidos) </p></li>
#
#  <div class="polaroid">
#    <img src="./Varios/imagenes/Lab127.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Carácteristica de los pascientes</p>
#   </div>
# </div>
#
#
# <p>Se observan diferentes motivos para concluir que es poco probable que esta característica determine la readmisión de los pascientes. Primero, las frecuencias relativas de las cuatro categorías de la característica son casi idénticas para los dos valores de la etiqueta. Segundo, todas las categorías de la característica, excepto none, son bastante infrecuentes, lo que significa que incluso si hubiera una diferencia significativa, estos valores solo separarían una minoría de casos.</p>
# </li>
#
# <li><p>En la característica weight, la etiqueta de "unknown" es predominante, esta característica es poco probable que contenga información significativa pues es pareceida para ambas clasifcaciones. </p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab128.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Carácteristica de los pascientes</p>
#   </div>
# </div>
# </li>
#
#
# <li><p>En la característica number_inapatient, se muestra tanto la gráfica de barras como la gáfica de caja </p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab129.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Gráfica de caja</p>
#   </div>
# </div>
# <div class="polaroid">
#    <img src="./Varios/imagenes/Lab130.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Gráfica de barras</p>
#   </div>
# </div>
#
# <p>Con base en observaciones puede esperarse que number_inpatient separe solo unos pocos casos y, por lo tanto, sea una característica deficiente.</p>
# </li>
#
# <li><p>Se muestrán las gráficas para la característica time_in_hospital</p>
#
#    <div class="polaroid">
#    <img src="./Varios/imagenes/Lab131.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Gráfica de caja</p>
#   </div>
# </div>
# <div class="polaroid">
#    <img src="./Varios/imagenes/Lab132.png" alt="Pareja" width="90%" height="90%">
#   <div class="despolaroid">
#     <p>Gráfica de barras</p>
#   </div>
# </div>
#
# <p> Hay un sesgo hacia un tiempo más largo en el hospital para los pacientes que son readmitidos. Sin embargo, dada la superposición de valores, esta función tiene una potencia limitada para separar las dos clases de la etiqueta. En el menu File del notebook, haga click en Close and Halt para cerrar la pestaña del navegador, regrese al experimento en Azure ML Studio.</p>
# </li>
# </ol>
#
# <h4>Construcción del modelo de clasificación</h4>
#
# <h4>Evaluación del modelo de clasificación</h4>
#
#
#
#
# <p>Los laboratorios fueron diseñados por Microsoft Learning y se distribuyen con <a href="https://github.com/MicrosoftLearning/Principles-Of-Machine-Learning/blob/master/LICENSE">MIT (licence)</a>. Los laboratorios completos se encuentran en el siguiente <a href="https://github.com/MicrosoftLearning/Principles-Of-Machine-Learning">enlace</a> </p>
#
# </div>
# </div>
# </div>

# %%
# %%javascript
# function main() {
#  // $('.skillset').hide();
#  //$('.skillset').fadeIn(1000);
#
#   $('.projects').hide();
#
#   $('.projects-button').on('click', function() {
#     //$(this).toggle('slow');
#       $(this).next().toggle('slow');
# 	});
# }
#
# $(document).ready(main);
